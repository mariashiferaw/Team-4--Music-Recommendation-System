# %%
import pandas as pd

# %%
df = pd.read_csv('spotify_song.csv')
df.head()
# Out:
#    Unnamed: 0                track_id  \
# 0           0  6f807x0ima9a1j3VPbc7VN
# 1           1  0r7CVbZTWZgbTCYdfa2P31
# 2           2  1z1Hg7Vb0AhHDiEmnDE79l
# 3           3  75FpbthrwQmzHlBJLuGdC7
# 4           4  1e8PAfcKUYoKkxPhrHqw4x
#
#                                           track_name      track_artist  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                    Memories - Dillon Francis Remix          Maroon 5
# 2                    All the Time - Don Diablo Remix      Zara Larsson
# 3                  Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4            Someone You Loved - Future Humans Remix     Lewis Capaldi
#
#    track_popularity          track_album_id  \
# 0                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1                67  63rPSO264uRjW1X5E6cWv6
# 2                70  1HoSmj2eLcsrR0vE9gThr4
# 3                60  1nqYsOef1yKKuGOVchbsk6
# 4                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
# ...

# %%
df.shape
# Out:
# (32833, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                32833 non-null  int64
#  1   track_id                  32833 non-null  object
#  2   track_name                32828 non-null  object
#  3   track_artist              32828 non-null  object
#  4   track_popularity          32833 non-null  int64
#  5   track_album_id            32833 non-null  object
#  6   track_album_name          32828 non-null  object
#  7   track_album_release_date  32833 non-null  object
#  8   playlist_name             32833 non-null  object
#  9   playlist_id               32833 non-null  object
#  10  playlist_genre            32833 non-null  object
#  11  playlist_subgenre         32833 non-null  object
#  12  danceability              32833 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  track_popularity  danceability        energy  \
# count  32833.000000      32833.000000  32833.000000  32833.000000
# mean   16416.000000         42.477081      0.654850      0.698619
# std     9478.215031         24.984074      0.145085      0.180910
# min        0.000000          0.000000      0.000000      0.000175
# 25%     8208.000000         24.000000      0.563000      0.581000
# 50%    16416.000000         45.000000      0.672000      0.721000
# 75%    24624.000000         62.000000      0.761000      0.840000
# max    32832.000000        100.000000      0.983000      1.000000
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000  32833.000000
# mean       5.374471     -6.719499      0.565711      0.107068      0.175334
# std        3.611657      2.988436      0.495671      0.101314      0.219633
# ...

# %%
#Check for Missing Values:
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
rows_with_missing_values = df[df.isnull().any(axis=1)]

print(rows_with_missing_values)
# Out:
#        Unnamed: 0                track_id track_name track_artist  \
# 8151         8151  69gRFGOWY9OMpFJgFol1u0        NaN          NaN
# 9282         9282  5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN
# 9283         9283  5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN
# 19568       19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN
# 19811       19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN
#
#        track_popularity          track_album_id track_album_name  \
# 8151                  0  717UG2du6utFe7CdmpuUe3              NaN
# 9282                  0  3luHJEPw434tvNbme3SP8M              NaN
# 9283                  0  3luHJEPw434tvNbme3SP8M              NaN
# 19568                 0  717UG2du6utFe7CdmpuUe3              NaN
# 19811                 0  717UG2du6utFe7CdmpuUe3              NaN
#
#       track_album_release_date       playlist_name             playlist_id  \
# 8151                2012-01-05             HIP&HOP  5DyJsJZOpMJh34WvUrQzMV
# ...

# %%
df1 = df.dropna()

df1
# Out:
#        Unnamed: 0                track_id  \
# 0               0  6f807x0ima9a1j3VPbc7VN
# 1               1  0r7CVbZTWZgbTCYdfa2P31
# 2               2  1z1Hg7Vb0AhHDiEmnDE79l
# 3               3  75FpbthrwQmzHlBJLuGdC7
# 4               4  1e8PAfcKUYoKkxPhrHqw4x
# ...           ...                     ...
# 32828       32828  7bxnKAamR3snQ1VGLuVfC1
# 32829       32829  5Aevni09Em4575077nkWHz
# 32830       32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831       32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832       32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...

# %%
#Check for Duplicated Values
df1.duplicated().sum()
# Out:
# 0

# %%
#Drop unnecessary columns 
spotify_songs = df1.drop(columns=['Unnamed: 0','track_album_id','track_album_release_date','key','mode'])

spotify_songs
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
#Convert duration from milliseconds to seconds 
spotify_songs['duration_ms'] = spotify_songs['duration_ms']*1000

# Renaming the column
spotify_songs.rename(columns={'duration_ms':'duration_s'}, inplace=True)

spotify_songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity  \
# 0        Ed Sheeran                66
# 1          Maroon 5                67
# 2      Zara Larsson                70
# 3  The Chainsmokers                60
# 4     Lewis Capaldi                69
#
#                                     track_album_name playlist_name  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...     Pop Remix
# 1                    Memories (Dillon Francis Remix)     Pop Remix
# ...

# %%
spotify_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32828 entries, 0 to 32832
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           32828 non-null  object
#  1   track_name         32828 non-null  object
#  2   track_artist       32828 non-null  object
#  3   track_popularity   32828 non-null  int64
#  4   track_album_name   32828 non-null  object
#  5   playlist_name      32828 non-null  object
#  6   playlist_id        32828 non-null  object
#  7   playlist_genre     32828 non-null  object
#  8   playlist_subgenre  32828 non-null  object
#  9   danceability       32828 non-null  float64
#  10  energy             32828 non-null  float64
#  11  loudness           32828 non-null  float64
#  12  speechiness        32828 non-null  float64
#  13  acousticness       32828 non-null  float64
#  14  instrumentalness   32828 non-null  float64
#  15  liveness           32828 non-null  float64
# ...

# %%
features = spotify_songs[['danceability', 'energy', 'loudness','speechiness','acousticness','instrumentalness','liveness','tempo','valence','duration_s']]

# %%
# Feature Correlation Matrix
import seaborn as sns
import matplotlib.pyplot as plt

music_features = ['danceability', 'energy', 'loudness','speechiness','acousticness','instrumentalness','liveness','tempo','valence','duration_s']
#Visualizing outliners by using box plots
plt.figure(figsize=(12,10))

for i,feature in enumerate(music_features,1):
    plt.subplot(5,2,i)
    sns.boxplot(y=spotify_songs[feature])
    plt.title(feature)

plt.show()

# %%
#Using Interquartile Range  (IQR) to identify outliers in a data set.

Q1 = spotify_songs[music_features].quantile(0.25)
Q3 = spotify_songs[music_features].quantile(0.75)

IQR = Q3 - Q1

outliers = ((spotify_songs[music_features] < (Q1 - 1.5 * IQR)) | (spotify_songs[music_features] > (Q3 + 1.5 * IQR))).any(axis=1)
outliers_indices = spotify_songs[outliers].index
num_outlier = outliers.sum()

num_outlier,outliers_indices
# Out:
# (13605,
#  Index([    8,    20,    21,    43,    44,    45,    60,    66,    67,    82,
#         ...
#         32812, 32814, 32816, 32817, 32819, 32823, 32827, 32829, 32831, 32832],
#        dtype='int64', length=13605))

# %%
#Calculate the correlation matrix 
corr_matrix = features.corr()

#Create heatmap to visualize the correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

# %%
#Analyzing 

#Danceability and Valence have a positive correletion (0.8). More danceable often have more postive mood
#Energy and Loudness also show a strong positive correlation. Louder tracks are often perceived as more energetic 
#Acousticness shows a negative correlation with energy and loudness. More acoustic tracks tend to be quier and less energic.
#Speechiness has moderate positive correlation with danceability and valence 
#Tempo also has a moderte positive with energy. faster-paced songs tend to be more energetic.
#Liveness shows a weak to moderate correlation with energy and loudness. Live recordings might have slightly higher energy and loudness, not significantly.
