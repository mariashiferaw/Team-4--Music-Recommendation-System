# %%
import pandas as pd

# %%
df_spotify = pd.read_csv('spotify_music.csv')

# %%
df_spotify.head()
# Out:
#    Unnamed: 0        album  track_number                      id  \
# 0           9  Thriller 40            10  4WGwTL5HIiaw5OIFnwgCR9
# 1          10  Thriller 40            11  21fVbhoPzmlLjxWfePb6CT
# 2          11  Thriller 40            12  5kMng2A15zTwpxiPHypbHm
# 3          13  Thriller 40            14  32gg7lWCipR6jYiz9qXwSo
# 4          14  Thriller 40            15  5yuLvy5xOhnhMZL0SjIZcX
#
#                                   name                                   uri  \
# 0                            Starlight  spotify:track:4WGwTL5HIiaw5OIFnwgCR9
# 1                  Got the Hots - Demo  spotify:track:21fVbhoPzmlLjxWfePb6CT
# 2               Who Do You Know - Demo  spotify:track:5kMng2A15zTwpxiPHypbHm
# 3  Behind The Mask - Mike's Mix (Demo)  spotify:track:32gg7lWCipR6jYiz9qXwSo
# 4             Can't Get Outta The Rain  spotify:track:5yuLvy5xOhnhMZL0SjIZcX
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# ...

# %%
#Check for Missing Values:
df_spotify.isnull().sum()
# Out:
# Unnamed: 0          0
# album               0
# track_number        0
# id                  0
# name                0
# uri                 0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# dtype: int64

# %%
#Remove duplicates
df_spotify.drop_duplicates(inplace=True)

# %%
#Drop column Unnamed
df_spotify_cleaned = df_spotify.drop(columns=["Unnamed: 0"])

df_spotify_cleaned
# Out:
#                album  track_number                      id  \
# 0        Thriller 40            10  4WGwTL5HIiaw5OIFnwgCR9
# 1        Thriller 40            11  21fVbhoPzmlLjxWfePb6CT
# 2        Thriller 40            12  5kMng2A15zTwpxiPHypbHm
# 3        Thriller 40            14  32gg7lWCipR6jYiz9qXwSo
# 4        Thriller 40            15  5yuLvy5xOhnhMZL0SjIZcX
# ..               ...           ...                     ...
# 211  Got To Be There             6  63gcHyuhAC8G2C0bVQUOJI
# 212  Got To Be There             7  5h6EHy1GvTcGrpedGZCPHL
# 213  Got To Be There             8  0w5Jpsn5Hr3CZkN2TvE681
# 214  Got To Be There             9  1UWM5Y6O7jU4ec2iaNn1os
# 215  Got To Be There            10  1jrJQ1Gib2ubaxAXe1z2Jc
#
#                                                name  \
# 0                                         Starlight
# 1                               Got the Hots - Demo
# 2                            Who Do You Know - Demo
# ...

# %%
df_spotify.shape
# Out:
# (216, 16)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features = df_spotify_cleaned[["acousticness","danceability","energy","instrumentalness","liveness","loudness","speechiness","tempo","valence","popularity"]]

# %%
#calculate the correlation matrix
corr_matrix = features.corr()

# %%
#create a figure with 10 inches wide and 8 inches height 
plt.figure(figsize=(10,8))
#create a heatmap displayed correlation coefficients with two decimal 
#Positive is warm color and Negative is cool color
sns.heatmap(corr_matrix,annot=True,fmt=".2f",cmap='coolwarm')
plt.title('Correlation Matrix of Spotify Music Features')
plt.show()

# %%
#Insights:

#Acousticness has strong negative correlation with energy (-0.69) => more acoustic, less energy and vice versa
#Danceability and Energy show moderate positive correlation (0.52) and negatrive (-0.52) with acousticeness => high engergy, danceable
#Energy has a strong postive correlation with Loudness (0.75) => louder, more energy
#Instrumentalness doesn't show strong correlation with most other features => distinct quality, not consistently vary with other features.
#Liveness has moderate positive correlation with Speechiness (0.51) => live recordings with audience interaction, more spoken words
#Valence and Danceability also have a moderate positive correlation (0.50) => a higher valence tend to more danceable
#Popularity does not have strong correlations with most audio features, the highest positive correlation is Loudness (0.34) and negative correlation is Speechiness (-0.34)
